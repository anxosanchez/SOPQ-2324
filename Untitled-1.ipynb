# %% [markdown]
# ---
# title: 'Reacción de primeiro orde nun tren de tres reactores CSTR'
# author: 'A. Sánchez'
# format:
#     html:
#     \usepackage{mhchem}
# ---
#
# Considera tres **CSTR** en serie, que operam a volume constante de $V$ = 100 L. Unha reacción de primeiro orde, $A → B + C$ ten lugar no sistema, con taxa de reacción = r = 0,09CA.As condicións de entrada ao primeiro reactor son constantes co tempo:
# Concentración de entrada = CA, 0 = 2,7 mol/L a un caudal de F0 en = 15,8 l/min.A saída do primeiro reactor, CA, 1, é a entrada ao segundo reactor, e a toma do segundo reactor, CA, 2, pasa ao terceiro reactor.A saída do terceiro reactor, CA, 3, pódese usar para calcular a conversión global = CA, 0 - CA, 3
#
# ```{python}
# CA0 = 5
# ```
#
# Os saldos dinámicos en cada reactor son:
#
# $$
# \frac { dC_{_1_} } { dt } = F V_1
# $$
#
# dCA,1(t)
# dt =
# F
# V1
#
# CA,0 − CA,1
#
# − kCA,1
# dCA,2(t)
# dt =
# F
# V2
#
# CA,1 − CA,2
#
# − kCA,2
# dCA,3(t)
# dt =
# F
# V3
#
# CA,2 − CA,3
#
# − kCA,3
#
# Describe como resolverías o sistema de ecuacións $f(x) = 0$ onde:
#
# $$
# x = C_{A_1},C_{A_2},C_{A_3}
# $$
#
# Use un solucionador ODE para atopar os valores en estado estacionario de $C_{A_1}$, $C_{A_2}$ e $C_{A_3}$, e tamén a conversion global do tren de reactores.
#
# You are tasked with increasing the conversion of the overall system. You are investigating two possibilities: adding a
# recycle stream, and operating at larger tank volumes.
#
# 2. What are the new steady state values of x =
#
# CA,1, CA,2, CA,3
#
# and the overall conversion when V1 = V2 =
# V3 = 150 L? Why does operating at a larger tank volumes increase conversion? You can answer this question
# even if you haven’t taken the reactor design course yet - hint: interpret the above modelling equations.
# 3. Let’s take a look at what happens when a disturbance enters the system. Simulate the case when a step change
# of +1.2 mol/L in CA,0 is made at time t = 50 (i.e. the inlet concentration is 2.7 mol/L for 50 minutes, then
# increased to 3.9 mol/L for the rest of the time). Choose suitable initial conditions so that your system is roughly
# at steady state before t = 50, continue the simulation on until the new steady state is reached.
# What do you notice about the shape of the concentration vs time trajectories from each reactor (superimpose the
# 3 trajectories on the same plot).
# Adding a recycle stream from the final reactor to the first or second reactor is an exercise that you can complete on
# your own. It leads to a counter-intuitive phenomenon: you’d expect an increase in conversion, but ....

# %%
CA0 = 5
